# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import read_and_plot

# %%
datasets = ['pacs']
nlabs = [210]
baselines = ['fixmatch']
imbalances = ['exp_l_only']
targets = [['photo', 'art_painting', 'cartoon', 'sketch']]
alphas = [0, 1, 2, 3, 5, 7]

for d, nl, t in zip(datasets, nlabs, targets):
    for bl in baselines:
        for i in imbalances:
            read_and_plot(
                dataset=d,
                nlab=nl,
                baseline=bl,
                imbalance=i,
                targets=t,
                weight_h=alphas,
                me='alpha'
            )

# %%
datasets = ['pacs']
nlabs = [105]
baselines = ['fixmatch']
imbalances = ['exp_l_only']
targets = [['photo', 'art_painting', 'cartoon', 'sketch']]
alphas = [0, 1, 2, 3, 5, 7]

for d, nl, t in zip(datasets, nlabs, targets):
    for bl in baselines:
        for i in imbalances:
            read_and_plot(
                dataset=d,
                nlab=nl,
                baseline=bl,
                imbalance=i,
                targets=t,
                weight_h=alphas,
                me='alpha'
            )

# %%
datasets = ['pacs']
nlabs = [210]
baselines = ['fixmatch']
imbalances = ['exp_l_only']
targets = [['photo', 'art_painting', 'cartoon', 'sketch']]
lambdas = [0, 0.1, 0.25, 0.5, 1]

for d, nl, t in zip(datasets, nlabs, targets):
    for bl in baselines:
        for i in imbalances:
            read_and_plot(
                dataset=d,
                nlab=nl,
                baseline=bl,
                imbalance=i,
                targets=t,
                weight_h=lambdas,
                me='shannon'
            )

# %%
datasets = ['pacs']
nlabs = [210]
baselines = ['flexmatch']
imbalances = ['exp_l_only']
targets = [['photo', 'art_painting', 'cartoon', 'sketch']]
lambdas = [0, 0.1, 0.25, 0.5, 1]

for d, nl, t in zip(datasets, nlabs, targets):
    for bl in baselines:
        for i in imbalances:
            read_and_plot(
                dataset=d,
                nlab=nl,
                baseline=bl,
                imbalance=i,
                targets=t,
                weight_h=lambdas,
                me='shannon'
            )
