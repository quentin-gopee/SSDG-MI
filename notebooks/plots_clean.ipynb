# %%
from utils import read_and_plot

# %%
datasets = ['pacs', 'officehome']
nlabs = [210, 1950]
setups = ['all_sources_l', 'one_source_l']
imbalances = ['original', 'exp_l_only']
targets = [['photo', 'art_painting', 'cartoon', 'sketch'], ['art', 'clipart', 'product', 'real_world']]
batch_sizes = [16, 32]
alphas = [0, 0.1, 0.5, 1]

for d, nl, t in zip(datasets, nlabs, targets):
    for s in setups:
        for i in imbalances:
            read_and_plot(
                dataset=d,
                nlab=nl,
                setup=s,
                imbalance=i,
                targets=t,
                batch_sizes=batch_sizes,
                alphas=alphas
            )
